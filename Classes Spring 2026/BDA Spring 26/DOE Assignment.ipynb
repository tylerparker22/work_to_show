# %%
# Blocking circle
# circle factorioal

# %%
import pandas as pd
from matplotlib.style.core import library

ac = pd.read_csv('Datasets/Automated checkouts.csv', sep = ',')

# %%
# run this by itself to run r
# %load_ext rpy2.ipython

# %%
# %%R -i ac
# # Covariate
# ac$Type <- as.factor(ac$Type)
# fit <- lm(EndSales ~ Type + PredictedSales, data = ac)
# anova(fit)
#
# ## Covariate follow-up
# library(emmeans)
# emm <- emmeans(fit, ~ Type)
# pairs(emm)
# emm

# %%
import pandas as pd
line_down = pd.read_csv('Datasets/Line downtime.csv', sep = ',')
print(line_down.columns.tolist()) # ['day', 'line', 'method', 'downtime']
# Out:
# ['day', 'line', 'method', 'downtime']

# %%
# %%R -i line_down
# # block
# library(agricolae)
# fit <- aov(downtime ~ method + line, data = line_down)
# summary(fit)
# duncan_results <- duncan.test(fit, "method", group = TRUE)
# print(duncan_results)
# Out:
# $statistics
#    MSerror Df     Mean       CV
#   47.59211 57 32.99921 20.90566
#
# $parameters
#     test name.t ntr alpha
#   Duncan method   2  0.05
#
# $duncan
#      Table CriticalRange
# 2 2.831914      3.566867
#
# $means
#     downtime      std  r       se      Min      Max      Q25      Q50      Q75
# new 30.65322 9.698313 30 1.259525 13.84695 51.50351 24.03512 29.91281 36.51905
# old 35.34519 8.486426 30 1.259525 19.19241 52.89310 29.26806 33.59254 42.18442
#
# $comparison
# NULL
#
# $groups
#     downtime groups
# old 35.34519      a
# new 30.65322      b
#
# attr(,"class")
# [1] "group"

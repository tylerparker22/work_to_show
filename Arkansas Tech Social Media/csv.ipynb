# %%
import sqlite3
import pandas as pd
import os

# Path to your database
DB_PATH = r"//sdata/susers/tparker27/My Documents/GitHub/work_to_show/Arkansas Tech Social Media/social_media.db"

# Output folder for CSVs (same directory as the DB)
OUTPUT_DIR = r"//sdata/susers/tparker27/My Documents/GitHub/work_to_show/Arkansas Tech Social Media"

# Connect to SQLite
conn = sqlite3.connect(DB_PATH)
cursor = conn.cursor()

# Get all table names
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
tables = cursor.fetchall()

# Export each table to its own CSV
for (table_name,) in tables:
    df = pd.read_sql_query(f"SELECT * FROM {table_name}", conn)
    csv_path = os.path.join(OUTPUT_DIR, f"{table_name}.csv")
    df.to_csv(csv_path, index=False)
    print(f"Exported '{table_name}' → {csv_path}  ({len(df)} rows)")

# Close connection
conn.close()
print("Done! Connection closed.")
# Out:
# Exported 'story' → //sdata/susers/tparker27/My Documents/GitHub/work_to_show/Arkansas Tech Social Media\story.csv  (1220 rows)
# Exported 'post' → //sdata/susers/tparker27/My Documents/GitHub/work_to_show/Arkansas Tech Social Media\post.csv  (268 rows)
# Done! Connection closed.

# %%
print(os.path.abspath(csv_path))
# Out:
# \\sdata\susers\tparker27\My Documents\GitHub\work_to_show\Arkansas Tech Social Media\post.csv

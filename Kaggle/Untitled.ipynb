# %%
# run this by itself to run r
# %load_ext rpy2.ipython
# Out:
# Error importing in API mode: ImportError('On Windows, cffi mode "ANY" is only "ABI".')
# Trying to import in ABI mode.

# %%
import pandas as pd
df = pd.read_csv("C:/Users/tyler/OneDrive/Documents/GitHub/work_to_show/Kaggle/local_test.csv")

# %%
# %%R -i df
# colnames(df)
# Out:
#  [1] "id_date_combined" "id"               "date"             "bedrooms"
#  [5] "bathrooms"        "sqft_living"      "sqft_lot"         "floors"
#  [9] "waterfront"       "view"             "condition"        "grade"
# [13] "sqft_above"       "sqft_basement"    "yr_built"         "yr_renovated"
# [17] "zipcode"          "lat"              "long"             "sqft_living15"
# [21] "sqft_lot15"       "price"
# C:\Users\tyler\anaconda3\Lib\site-packages\rpy2\robjects\pandas2ri.py:65: UserWarning: Error while trying to convert the column "id". Fall back to string conversion. The error is: integer 9211500560 does not fit 'int'
#   warnings.warn('Error while trying to convert '

# %%
print(df.columns.tolist())
# Out:
# ['id_date_combined', 'id', 'date', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade', 'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long', 'sqft_living15', 'sqft_lot15', 'price']

# %%
# data processing
new = df.drop(['id_date_combined', 'id', 'date'], axis=1)
for column in new.select_dtypes(include=['object']).columns:
    print(f"Unique values {column}: {new[column].unique()}")

# %%
#  One-Hot Encoding
df_encoded = pd.get_dummies(new, columns=['view', 'condition', 'grade'], drop_first=True)
df_encoded
# Out:
#      bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0           3       2.00         1690      6790     1.0           0
# 1           2       1.75         2320      5500     1.5           0
# 2           4       1.75         2020     36400     1.0           0
# 3           4       2.50         2580     15031     2.0           0
# 4           3       2.00         1540      6000     1.0           0
# ..        ...        ...          ...       ...     ...         ...
# 860         4       1.75         3220      7392     1.0           0
# 861         4       3.00         5940     11533     2.0           0
# 862         3       2.50         1690      4533     2.0           0
# 863         3       2.75         2290      5002     2.0           0
# 864         3       2.25         1670      4800     1.5           0
#
#      sqft_above  sqft_basement  yr_built  yr_renovated  ...  condition_4  \
# 0          1360            330      1979             0  ...        False
# ...

# %%
from sklearn.preprocessing import StandardScaler
import numpy as np
numeric_columns = df_encoded.select_dtypes(include=[np.number]).columns
scaler = StandardScaler()
df_scaled = df_encoded.copy()
df_scaled[numeric_columns] = scaler.fit_transform(df_encoded[numeric_columns])

# %%
right_now = 2026

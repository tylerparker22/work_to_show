# %%
import pandas as pd
df = pd.read_csv("C:/Users/tyler/OneDrive/Documents/GitHub/work_to_show/Kaggle/local_test.csv")

# %%
# look at data
print(df.shape)
print(df.info())
print(df.describe())
# Out:
# (865, 22)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 865 entries, 0 to 864
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id_date_combined  865 non-null    object
#  1   id                865 non-null    int64
#  2   date              865 non-null    object
#  3   bedrooms          865 non-null    int64
#  4   bathrooms         865 non-null    float64
#  5   sqft_living       865 non-null    int64
#  6   sqft_lot          865 non-null    int64
#  7   floors            865 non-null    float64
#  8   waterfront        865 non-null    int64
#  9   view              865 non-null    int64
#  10  condition         865 non-null    int64
#  11  grade             865 non-null    int64
#  12  sqft_above        865 non-null    int64
#  13  sqft_basement     865 non-null    int64
#  14  yr_built          865 non-null    int64
#  15  yr_renovated      865 non-null    int64
# ...
